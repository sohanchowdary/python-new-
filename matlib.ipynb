# %% [markdown]
# <a href="https://colab.research.google.com/github/sohanchowdary/python-new-/blob/module-4/matlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Pyplot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([20,40,60,80,100])
y = np.array([250,50,200,50,250 ])

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Plotting

# %%
#Plotting x and y points
x =np.array([ 8,6])
y = np.array([ 10,5])
plt.plot(x, y)
plt.show()

#Plotting Without Line
x = np.array([1, 8])
y = np.array([3, 10])
plt.plot(x, y, 's')
plt.show()

#Multiple Points
x = np.array([1, 2, 6, 8])
y = np.array([3, 8, 1, 10])
plt.plot(x, y)
plt.show()

#Default X-Points
y = np.array([3, 8, 1, 10, 5, 7])
plt.plot(y)
plt.show()

# %% [markdown]
# #### Markers

# %%
#Markers
y = np.array([9, 8, 9, 10])
plt.plot(y, marker = 'o')
plt.show()

#Marker Reference
y = np.array([3, 8, 15, 10])
plt.plot(y, marker = 'X')
plt.show()

#Format Strings
y = np.array([3, 9, 1, 10])
plt.plot(y, 'x--y')
plt.show()

#Marker Size
y = np.array([3, 2, 1, 6])
plt.plot(y, marker = 'd', ms = 10)
plt.show()

#Marker Color
y = np.array([3, 2, 1, 10])
plt.plot(y, marker = 'o', ms = 20, mec = 'r')
plt.show()

y = np.array([15, 8, 1, 10])
plt.plot(y, marker = 'o', ms = 20, mfc = 'r')
plt.show()

y = np.array([3, 8, 96, 10])
plt.plot(y, marker = 'o', ms = 20, mec = 'r', mfc = 'r')
plt.show()

y = np.array([3, 8, 9, 10])
plt.plot(y, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

y = np.array([3, 8, 9, 10])
plt.plot(y, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %% [markdown]
# ####Line

# %%
#Linestyle
y = np.array([9, 8, 1, 10])
plt.plot(y, linestyle = 'dotted')
plt.show()

y = np.array([9, 8, 1, 10])
plt.plot(y, ls = ':')
plt.show()

#Line color
y = np.array([3, 1, 1, 10])
plt.plot(y, color = 'r')
plt.show()

#Line Width
y = np.array([3, 8, 1, 10])
plt.plot(y, linewidth = '6.9')
plt.show()

#Multiple Lines
y1 = np.array([18, 8, 4, 10])
y2 = np.array([6, 2, 7, 11])
plt.plot(y1,c="m")
plt.plot(y2,c="r")
plt.show()

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# #### Labels and Title

# %%
#Create Labels for a Plot
x = np.array([80, 85, 95, 110, 100, 105, 85, 115, 90, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

#Set Font Properties for Title and Labels
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

#Position the Title
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.show()

plt.title("Sports Watch Data", loc = 'right')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Grid Lines

# %%
#Add Grid Lines to a Plot
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid()
plt.show()

#Specify Which Grid Lines to Display
plt.plot(x, y)
plt.grid(axis = 'x')
plt.show()

plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

#Set Line Properties for the Grid
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 1)
plt.show()

# %% [markdown]
# #### Subplot

# %%
#Display Multiple Plots
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 15, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)

#(plot 2:)
x = np.array([0, 1, 2, 3])
y = np.array([10, 50, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

#Subplot() Function
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 1, 2)
plt.plot(x,y)
plt.show()

#Many plots
x = np.array([0, 5, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 50, 40])
plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 6, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 5, 30, 40])
plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.show()

#Title
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()
#Super Title
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 2, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 10, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# #### Scatter

# %%
#Creating Scatter Plots
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

#Compare Plots
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

#Colors
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')
plt.show()

#Color Each Dot
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=colors)
plt.show()

#ColorMap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x, y, c=colors, cmap='viridis')
plt.show()

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])
plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()

#Size
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, s=sizes)
plt.show()

#Alpha
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x, y, s=sizes, alpha=0.5)
plt.show()

#Combine Color Size and Alpha
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %% [markdown]
# #### Bars

# %%
#Creating Bars
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

#Horizontal Bars
plt.barh(x, y)
plt.show()

#Bar Color
plt.bar(x, y, color = "red")
plt.show()

#Color Names
plt.bar(x, y, color = "hotpink")
plt.show()

#Color Hex
plt.bar(x, y, color = "#4CAF50")
plt.show()

#Bar Width
plt.bar(x, y, width = 0.1)
plt.show()

#Bar Height
plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# #### Histograms

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# #### Pie Charts

# %%
#Creating Pie Charts
y = np.array([35, 25, 25, 15])
plt.pie(y)
plt.show()

#Labels
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.show() 

#Start Angle
plt.pie(y, labels = mylabels, startangle = 90)
plt.show() 

#Explode
myexplode = [0.2, 0.1, 0, -0.1]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

#Shadow
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

#Colors
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()
